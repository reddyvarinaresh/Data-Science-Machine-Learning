# %% [markdown]
# ## Exploratory Data Analysis
#
# ## Cleaning of Data,Exploration of Data to make it consistent for Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\reddyvari.n\\Downloads\\Algorithms_practiced\\HR Analytics'

# %%
df=pd.read_csv('Employee_Performance.csv')

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %%
## Summary statistics for numerical fields

df.corr().tail()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# ExperienceYearsAtThisCompany  0.318852          0.021908           0.076332
# ExperienceYearsInCurrentRole  0.217163          0.019898           0.066672
# YearsSinceLastPromotion       0.228199          0.013246           0.054313
# YearsWithCurrManager          0.205098          0.017860           0.088988
# PerformanceRating            -0.040164         -0.046142           0.020529
#
#                               EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ExperienceYearsAtThisCompany                   -0.000561      -0.000399
# ExperienceYearsInCurrentRole                    0.025491      -0.011871
# YearsSinceLastPromotion                         0.010732      -0.010000
# YearsWithCurrManager                           -0.011702      -0.004576
# PerformanceRating                               0.395561      -0.043116
#
#                               EmpJobInvolvement  EmpJobLevel  \
# ...

# %%
# Check for Null values

df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df.shape
# Out:
# (1200, 28)

# %%
df.drop(columns='EmpNumber',inplace=True) # Remvoving Employee number which is not of any value

# %%
df
# Out:
#       Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0      32    Male           Marketing        Single            Sales
# 1      47    Male           Marketing        Single            Sales
# 2      40    Male       Life Sciences       Married            Sales
# 3      41    Male     Human Resources      Divorced  Human Resources
# 4      60    Male           Marketing        Single            Sales
# 5      27    Male       Life Sciences      Divorced      Development
# 6      50    Male           Marketing       Married            Sales
# 7      28  Female       Life Sciences        Single      Development
# 8      36  Female       Life Sciences       Married      Development
# 9      38  Female       Life Sciences        Single      Development
# 10     44    Male             Medical        Single      Development
# 11     47  Female             Medical      Divorced            Sales
# 12     30    Male           Marketing      Divorced            Sales
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df.Gender=l.fit_transform(df.Gender)
df.EducationBackground=l.fit_transform(df.EducationBackground)
df.MaritalStatus=l.fit_transform(df.MaritalStatus)
df.EmpDepartment=l.fit_transform(df.EmpDepartment)
df.EmpJobRole=l.fit_transform(df.EmpJobRole)
df.BusinessTravelFrequency=l.fit_transform(df.BusinessTravelFrequency)
df.Attrition=l.fit_transform(df.Attrition)
df.OverTime=l.fit_transform(df.OverTime)

# %%
df.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    2              2              5          13
# 1   47       1                    2              2              5          13
# 2   40       1                    1              1              5          13
# 3   41       1                    0              0              3           8
# 4   60       1                    2              2              5          13
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        2                10                  3
# 1                        2                14                  4
# 2                        1                 5                  4
# 3                        2                10                  4
# 4                        2                16                  4
#
#    EmpEnvironmentSatisfaction        ...          EmpRelationshipSatisfaction  \
# ...

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10,5
sb.set_style('whitegrid')

sb.heatmap(df)

# %%
sb.pairplot(df)

# %% [markdown]
# ## Department wise performances

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10,5
sb.set_style('whitegrid')

# %%
x=df['EmpDepartment']

# %%
y=df['PerformanceRating']

# %%
sb.barplot(x,y)
